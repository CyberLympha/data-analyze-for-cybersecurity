# %% [markdown]
# #Применение сверточных нейронных сетей для обнаружения сетевых атак

# %% [markdown]
# Файл с данными (см. Лаб. 4.1)
#
# Intr_Det_Dense_Lab4.csv

# %% [markdown]
# ## Задачи:
#
# - сделайте обработку данных (см. Лаб. 4.1)
# - разделите датасет на метки и признаки
#
#
# 1. Одномерная сверточная нейронная сеть для обнаружения атаки.
# - разделите данные на обучающую и тестовую выборки. Сделайте нормализацию
# - подберите архитектуру 1D CNN (1-2 слоя)
# - подберите оптимальные гиперпараметры (кол-во эпох, размер пакетов и т.п.)
# - сделайте оценку вашей модели.
#
#
# 2. Двумерная сверточная нейронная сеть для обнаружения атаки.
# - каждую запись (строку) представьте в виде матрицы $n\times n$. Сделайте нормализацию
# - разделите данные на обучающую и тестовую выборки
# - реализуйте модель 2D CNN (1-2 слоя)
# - подберите оптимальные гиперпараметры (кол-во эпох, размер пакетов и т.п.)
# - сделайте оценку вашей модели.
#
#
# 3. Полученные результаты сравните результатом Лаб.4.1. Какая модель показала лучшую точность?
